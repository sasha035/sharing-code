# %% [markdown]
# # Weekly Assignment #2
# ### 1. Your data pre-processing steps

# %%
#importing all that is necessary and reading the files 
import seaborn as sns #this is the plotting library I'll be using 
import pandas as pd #"as pd" means that we can use the abbreviation in commands
import matplotlib.pyplot as plt #we need Matplotlib for setting the labels in the Seaborn graphs

df1 = pd.read_csv('survey.csv')
df2 = pd.read_csv('steps.csv', sep=';')
df1.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight
# 0   178.0    98.0
# 1   180.0    77.0
# 2   180.0    83.0
# 3   178.0    80.0
# 4   167.0    61.0

# %%
df2.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  4-5-2014  5-5-2014  6-5-2014  \
# 0     9929.0    12879.0    10541.0  ...       NaN       NaN       NaN
# 1     4024.0     3926.0    14595.0  ...       NaN       NaN       NaN
# 2     8185.0     9630.0     8983.0  ...    3914.0    4364.0       NaN
# 3        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 4        NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#    7-5-2014  8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014
# ...

# %% [markdown]
# ### 2. Create the variable mean steps per participant
# ### 3. The head() of the resulting data frame

# %%
#Create the variable mean steps per participant. Hint: combine Pandas .loc and .mean() with the right axis argument (axis=....) for mean(). 
mean_steps = df.loc[:, "20-6-2013":"13-5-2014"].mean(axis=1)
mean_steps.index
mean_steps.head()

#The head() of the resulting data frame
df2['Mean_steps'] = mean_steps
df2.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  5-5-2014  6-5-2014  7-5-2014  \
# 0     9929.0    12879.0    10541.0  ...       NaN       NaN       NaN
# 1     4024.0     3926.0    14595.0  ...       NaN       NaN       NaN
# 2     8185.0     9630.0     8983.0  ...    4364.0       NaN       NaN
# 3        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 4        NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#    8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014  \
# ...

# %%
#Merge files together
df = pd.merge(df1, df2, on = 'id') #'id' is the common identifier
df.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight  20-6-2013  ...  5-5-2014  6-5-2014  7-5-2014  8-5-2014  \
# 0   178.0    98.0        NaN  ...       NaN       NaN       NaN       NaN
# 1   180.0    77.0        NaN  ...       NaN       NaN       NaN       NaN
# 2   180.0    83.0        NaN  ...    4364.0       NaN       NaN       NaN
# 3   178.0    80.0        NaN  ...       NaN       NaN       NaN       NaN
# 4   167.0    61.0        NaN  ...       NaN       NaN       NaN       NaN
#
#    9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014    Mean_steps
# ...

# %%
df.info() #Get information on the variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 929 entries, 0 to 928
# Columns: 338 entries, id to Mean_steps
# dtypes: float64(331), int64(3), object(4)
# memory usage: 2.4+ MB

# %%
#Replace all na values with 0
df.fillna(0)
# Out:
#       id         city  gender    age  hh_size  education          education_1  \
# 0      1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1      2        Lille    Male  35-44        1          3             Bachelor
# 2      3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3      4         Lyon    Male    <25        1          1             Bachelor
# 4      5  Montpellier  Female  25-34        3          4             Bachelor
# ..   ...          ...     ...    ...      ...        ...                  ...
# 924  925        Lille  Female  45-54        3          4  Master or doctorate
# 925  926        Lille    Male    <25        3          5             Bachelor
# 926  927  Montpellier    Male  35-44        2          2             Bachelor
# 927  928        Lille  Female  55-64        1          1          High school
# 928  929         Lyon    Male  25-34        2          2          High school
#
# ...

# %%
#remove data with 65000 steps or more (+/- 50km)
def above_65000(x):
    if(x > 65000.0): 
        return float('NaN')
    else: 
        return x
df['Mean_steps'] = df['Mean_steps'].apply(above_65000)

df.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight  20-6-2013  ...  5-5-2014  6-5-2014  7-5-2014  8-5-2014  \
# 0   178.0    98.0        NaN  ...       NaN       NaN       NaN       NaN
# 1   180.0    77.0        NaN  ...       NaN       NaN       NaN       NaN
# 2   180.0    83.0        NaN  ...    4364.0       NaN       NaN       NaN
# 3   178.0    80.0        NaN  ...       NaN       NaN       NaN       NaN
# 4   167.0    61.0        NaN  ...       NaN       NaN       NaN       NaN
#
#    9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014    Mean_steps
# ...

# %% [markdown]
# ### 3. The relation of meansteps per participant
# with at least 2 other quantitative variables (e.g., how are steps related to weight, height).

# %% [markdown]
# #### 3a.Correlation matrix including all 3 variables

# %%
#Create dataframe with variables I want to use for Correlation matrix.
#Select columns with quantitative variables (3x)
df_var = df[["height", "weight", "Mean_steps"]]
df_var.head()
# Out:
#    height  weight    Mean_steps
# 0   178.0    98.0  10205.521212
# 1   180.0    77.0   5687.423313
# 2   180.0    83.0   8301.729730
# 3   178.0    80.0   3633.200000
# 4   167.0    61.0   5312.129630

# %%
#Make correlation matrix
sns.pairplot(df_var)
plt.show()

# %%
#Making a heatmap
corr = df[['height', 'weight', 'Mean_steps']].corr()
corr
# Out:
#               height    weight  Mean_steps
# height      1.000000  0.265138   -0.097515
# weight      0.265138  1.000000   -0.048404
# Mean_steps -0.097515 -0.048404    1.000000

# %%
#make heat map
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns) #the last two arguments set the column names
plt.show()

# %% [markdown]
# #### 3b. Scatter plots of your variable with the 2 other variables (2 scatter plots in total)

# %%
#Make scatterplot: pattern in means of steps and height
sns.scatterplot(data=df, x="height", y="Mean_steps")

# %%
#Make scatterplot: pattern in means of steps and weight
sns.scatterplot(data=df, x="weight", y="Mean_steps")

# %% [markdown]
# #### 3c. Pearson’s correlation for the 2 relations

# %%
#Calculate Pearson’s r for combination height/mean steps
df_height_steps=df_var.drop(columns="weight")
df_height_steps.corr()
# Out:
#               height  Mean_steps
# height      1.000000   -0.097515
# Mean_steps -0.097515    1.000000

# %%
#Calculate Pearson’s r for combination weight/mean steps
df_weight_steps=df_var.drop(columns="height")
df_weight_steps.corr()
# Out:
#               weight  Mean_steps
# weight      1.000000   -0.048404
# Mean_steps -0.048404    1.000000

# %%
#checking if any contain infs or NaNs
import numpy as np
import sklearn.cross_decomposition

np.isnan(df["weight"]).any()
np.isnan(df["Mean_steps"]).any()

np.isinf(df["weight"]).any()
np.isinf(df["Mean_steps"]).any()

np.isnan(df["height"]).any()
np.isnan(df["Mean_steps"]).any()

np.isinf(df["height"]).any()
np.isinf(df["Mean_steps"]).any()
# Out:
# False

# %% [markdown]
# #### 3d. Verbal description of the relations, including strength of the association, linearity, etc.
# The correlation between height and the mean of steps is -0.097515, which indicates a weak negative relationship.
#
# The correlation between weight and the mean of steps is -0.048404, which also indicate a weak negative relationship. Even weaker than the correlation of height and means of steps.

# %% [markdown]
# ### 4. The relation of mean steps per participant with a qualitative variable with two levels
# (e.g. gender, weekday vs weekend)

# %%
#A simple bar plot (not stacked) of the relation between the variables
ax = sns.barplot(x="gender", y="Mean_steps", data=df)

# %% [markdown]
# #### 4b. Description of relation
# This graph shows the relation between a categorical variable (gender) and a numerical variable (Mean of steps). It shows that the female participants have a higher amount of average steps per day than males.

# %% [markdown]
# ### 5. The relation between two qualitative variables
#     a. Graphs of the relation (e.g., bar plot)
#     b. Cross table with relevant percentages
#     c. Verbal description of the relation

# %% [markdown]
# #### 5a. Graphs of the relation (e.g., bar plot)

# %%
#Two qualitative variables: gender and city
sns.countplot(x="gender", hue="city", data=df)
plt.show()

# %% [markdown]
# ##### 5b. Cross table with relevant percentages

# %%
#crosstable with proportions in %
pd.crosstab(df["gender"], df["city"], normalize="columns")*100
# Out:
# city     Bordeaux     Lille       Lyon  Montpellier
# gender
# Female  43.410853  50.09901  46.478873    39.215686
# Male    56.589147  49.90099  53.521127    60.784314

# %% [markdown]
# #### 5c. Verbal description of the relation
# When you look at the graph you can see that most of the participants (male and female) live in Lille. There are slight differences in distribution of male/female in the cities Bordeaux, Lille and Lyon. The biggest difference in distribution of gender is visible in Montpellier: 39.215686% female and 60.784314% males.
